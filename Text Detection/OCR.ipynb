# %%
import cv2
import pytesseract
import matplotlib.pyplot as plt

# %%
# load the example image and convert it to grayscale
image = cv2.imread("/Users/Starkjing/Desktop/ComputerVision/Text Detection/vrkIj.png")
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
text = pytesseract.image_to_string(image)
print(text)
plt.imshow(image)
# Out:
# lam curious about
# area-filling text
# rendering options
